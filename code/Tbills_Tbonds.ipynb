# %%
# import packages
import numpy as np
import pandas as pd
import os
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
# Path to the folder containing the chunked data
data_folder = "../data/"
output_folder = "../output/"

# Load data
bills = pd.read_excel(data_folder + "T-bills auction results_Federal ministy of finance.xlsx")
bonds = pd.read_excel(data_folder + "T-bonds auction results_Federal ministry of finance.xlsx")
# Out:
# /Users/ramzi.chariag/opt/anaconda3/lib/python3.9/site-packages/openpyxl/worksheet/header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
# /Users/ramzi.chariag/opt/anaconda3/lib/python3.9/site-packages/openpyxl/worksheet/header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %%
bills
# Out:
#                                             Unnamed: 0           Unnamed: 1
# 0                         Trezorski zapisi 3M - 91 dan                  NaN  \
# 1                                                  NaN                  NaN
# 2                                                R.br.        Datum aukcije
# 3                                                  NaN                  NaN
# 4                                                    1  2014-02-18 00:00:00
# ..                                                 ...                  ...
# 96                          Sveukupno trezorski zapisi                  NaN
# 97                          Sveukupno trezorski zapisi                  NaN
# 98                                                 NaN                  NaN
# 99   Izvor: Federalno ministarstvo finansija-Federa...                  NaN
# 100          Posljednje ažuriranje: 17.03.2023. godine                  NaN
#
# ...
